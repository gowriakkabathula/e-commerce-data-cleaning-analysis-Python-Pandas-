# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\glory\OneDrive\Desktop\csv files\E-Commerce raw data.csv",encoding ='latin1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (541909, 8)

# %%
#removing duplicates
df=df.drop_duplicates()

# %%
#Handling missing values
df= df.dropna(subset=['CustomerID'])

# %%
df['CustomerID'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: CustomerID, Length: 401604, dtype: bool

# %%
df['Description']=df['Description'].fillna('Unknown')

# %%
#Fixing data types
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  170492 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.6+ MB

# %%
df['UnitPrice']
# Out:
# 0         2.55
# 1         3.39
# 2         2.75
# 3         3.39
# 4         3.39
#           ...
# 541904    0.85
# 541905    2.10
# 541906    4.15
# 541907    4.15
# 541908    4.95
# Name: UnitPrice, Length: 401604, dtype: float64

# %%
#Removing negative or zero quantity
df=df[df['Quantity'] > 0]

# %%
df=df[df['UnitPrice']>0]

# %%
#Creating a new column
df['TotalPrice']=df['UnitPrice']*df['Quantity']

# %%
df['TotalPrice']
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: TotalPrice, Length: 392692, dtype: float64

# %%
df.loc[:,'Year']=df['InvoiceDate'].dt.year.astype(int)

# %%
df['Year']
# Out:
# 0         2010.0
# 1         2010.0
# 2         2010.0
# 3         2010.0
# 4         2010.0
#            ...
# 541904    2011.0
# 541905    2011.0
# 541906    2011.0
# 541907    2011.0
# 541908    2011.0
# Name: Year, Length: 166363, dtype: float64

# %%
df=df.dropna(subset=['InvoiceDate'])

# %%
df['Month']=df['InvoiceDate'].dt.month_name()

# %%
df['Month']
# Out:
# 0         December
# 1         December
# 2         December
# 3         December
# 4         December
#             ...
# 541904    December
# 541905    December
# 541906    December
# 541907    December
# 541908    December
# Name: Month, Length: 166363, dtype: object

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# TotalPrice     0
# Year           0
# Month          0
# dtype: int64

# %%
pd.set_option('display.max_rows',541910)

# %%
df

# %%
df.to_csv("Cleaned_E-Commerce_data.csv",index=False)
